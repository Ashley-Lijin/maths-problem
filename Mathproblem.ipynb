# %% [markdown]
#  ***Question***
# (i) find the amount to be paid when parking time is 6 hr; (ii) find the parking duration when the amount paid is ₹150.

# %% [markdown]
# ### importing dependendencies

# %%
import pandas as pd
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# ### **connecting to drive**
# (not requird if you are using jupitor notebook or any else)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #  **Solution**

# %% [markdown]
# importing the csv file

# %%
df = pd.read_csv('/content/drive/MyDrive/ml/math problem/math.csv')
df
# Out:
#    time  amonunt
# 0     4       60
# 1     8      120
# 2    12      180
# 3    24      360

# %% [markdown]
# **graph **
# (just for visualization)

# %%
plt.plot(df.time,df.amonunt)

# %% [markdown]
# ## solution for amount in given time

# %%
soln = lm.LinearRegression()
soln.fit(df[['time']],df.amonunt)
# Out:
# LinearRegression()

# %%
soln.predict([[6]])
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([90.])

# %% [markdown]
# ## solution for amount in given time

# %%
soln = lm.LinearRegression()
soln.fit(df[['amonunt']],df.time)
# Out:
# LinearRegression()

# %%
soln.predict([[150]])
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([10.])
